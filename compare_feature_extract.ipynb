# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
convnext = np.asarray([0.8705, 0.8768, 0.8989, 0.8931, 0.8903 ])
efficientnet = np.asarray([0.8934,0.9044, 0.9049, 0.9082, 0.9029])
training_set_size = np.asarray([25, 50, 75, 100, 125])

# %%
plt.figure()
#plt.bar(training_set_size-0.5, convnext,width = 0.5, label='ConvNext-T')
plt.plot(training_set_size, convnext,'x', label='ConvNext-T')
plt.plot(training_set_size, efficientnet,'o',label='EfficientNet-B5')
plt.xlabel('Training set size')
plt.xticks(training_set_size)
plt.ylabel('auROC')
plt.title('NFFA dataset')
plt.legend()
